# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\THINKPAD\Downloads\Program_Impact.csv")

# %%
df.head(10)
# Out:
#   Month             Region    District                       Program  \
# 0   Jan             Kigali      Gasabo             Education Support
# 1   Jan   Eastern Province      Kirehe               Food Assistance
# 2   Jan  Southern Province        Huye           Healthcare Outreach
# 3   Feb             Kigali  Nyarugenge           Livelihood Training
# 4   Feb   Eastern Province    Bugesera             Education Support
# 5   Feb   Western Province      Rubavu  Protection & Case Management
# 6   Mar             Kigali      Gasabo               Food Assistance
# 7   Mar   Eastern Province      Kirehe           Healthcare Outreach
# 8   Mar  Southern Province        Huye           Livelihood Training
# 9   Apr             Kigali  Nyarugenge  Protection & Case Management
#
#                      Target Group  Beneficiaries Reached  \
# 0     Refugees & Vulnerable Youth                    320
# 1  Refugees & Low-income Families                    540
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Month                    36 non-null     object
#  1   Region                   36 non-null     object
#  2   District                 36 non-null     object
#  3   Program                  36 non-null     object
#  4   Target Group             36 non-null     object
#  5   Beneficiaries Reached    36 non-null     int64
#  6   Female Beneficiaries     36 non-null     int64
#  7   Male Beneficiaries       36 non-null     int64
#  8   Children Supported       36 non-null     int64
#  9   Refugees Supported       36 non-null     int64
#  10  Local Vulnerable People  36 non-null     int64
#  11  Training Sessions        36 non-null     int64
#  12  Cases Resolved           36 non-null     int64
#  13  Satisfaction Rate %      36 non-null     int64
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df["Region"].unique()
df["Program"].unique()
df["Target Group"].unique()
# Out:
# array(['Refugees & Vulnerable Youth', 'Refugees & Low-income Families',
#        'Women & Children', 'Youth & Women', 'Refugees & At-risk Families'],
#       dtype=object)

# %%
df["Gender_Total"] = (
    df["Female Beneficiaries"]
    + df["Male Beneficiaries"]
)

df[
    df["Gender_Total"]
    != df["Beneficiaries Reached"]
]
# Out:
# Empty DataFrame
# Columns: [Month, Region, District, Program, Target Group, Beneficiaries Reached, Female Beneficiaries, Male Beneficiaries, Children Supported, Refugees Supported, Local Vulnerable People, Training Sessions, Cases Resolved, Satisfaction Rate %, SDG Alignment, Program_ID, Quarter, Gender_Total]
# Index: []

# %%
df["Region"].unique()
df["District"].unique()
df["Program"].unique()
df["SDG Alignment"].unique()
# Out:
# array(['SDG 4 - Quality Education', 'SDG 2 - Zero Hunger',
#        'SDG 3 - Good Health', 'SDG 8 - Decent Work',
#        'SDG 10 - Reduced Inequalities'], dtype=object)

# %%
# Gender counts match total
(
    df["Female Beneficiaries"]
    + df["Male Beneficiaries"]
    == df["Beneficiaries Reached"]
).all()
# Out:
# True

# %%
# Satisfaction rate valid
df["Satisfaction Rate %"].between(0,100).all()
# Out:
# True

# %%
# No duplicate Program_ID
df["Program_ID"].duplicated().sum()
# Out:
# 31

# %%
month_map = {
    "Jan": 1,
    "Feb": 2,
    "Mar": 3,
    "Apr": 4,
    "May": 5,
    "Jun": 6,
    "Jul": 7,
    "Aug": 8,
    "Sep": 9,
    "Oct": 10,
    "Nov": 11,
    "Dec": 12
}

df["Month_Number"] = df["month"].map(month_map)

# %%
df.head(10)
# Out:
#   month             region    district                       program  \
# 0   Jan             Kigali      Gasabo             Education Support
# 1   Jan   Eastern Province      Kirehe               Food Assistance
# 2   Jan  Southern Province        Huye           Healthcare Outreach
# 3   Feb             Kigali  Nyarugenge           Livelihood Training
# 4   Feb   Eastern Province    Bugesera             Education Support
# 5   Feb   Western Province      Rubavu  Protection & Case Management
# 6   Mar             Kigali      Gasabo               Food Assistance
# 7   Mar   Eastern Province      Kirehe           Healthcare Outreach
# 8   Mar  Southern Province        Huye           Livelihood Training
# 9   Apr             Kigali  Nyarugenge  Protection & Case Management
#
#                      target_group  beneficiaries_reached  \
# 0     Refugees & Vulnerable Youth                    320
# 1  Refugees & Low-income Families                    540
# ...

# %%
df["Month_Number"] = df["Month_Number"].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   month                    36 non-null     object
#  1   region                   36 non-null     object
#  2   district                 36 non-null     object
#  3   program                  36 non-null     object
#  4   target_group             36 non-null     object
#  5   beneficiaries_reached    36 non-null     int64
#  6   female_beneficiaries     36 non-null     int64
#  7   male_beneficiaries       36 non-null     int64
#  8   children_supported       36 non-null     int64
#  9   refugees_supported       36 non-null     int64
#  10  local_vulnerable_people  36 non-null     int64
#  11  training_sessions        36 non-null     int64
#  12  cases_resolved           36 non-null     int64
#  13  satisfaction_rate_pct    36 non-null     int64
# ...

# %%
df.columns = df.columns.str.lower()
df.columns = df.columns.str.replace(' ','_')

# %%
df.rename(columns={"satisfaction_rate_%": "satisfaction_rate_pct"}, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   month                    36 non-null     object
#  1   region                   36 non-null     object
#  2   district                 36 non-null     object
#  3   program                  36 non-null     object
#  4   target_group             36 non-null     object
#  5   beneficiaries_reached    36 non-null     int64
#  6   female_beneficiaries     36 non-null     int64
#  7   male_beneficiaries       36 non-null     int64
#  8   children_supported       36 non-null     int64
#  9   refugees_supported       36 non-null     int64
#  10  local_vulnerable_people  36 non-null     int64
#  11  training_sessions        36 non-null     int64
#  12  cases_resolved           36 non-null     int64
#  13  satisfaction_rate_pct    36 non-null     int64
# ...

# %%
pip install psycopg2-binary sqlalchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg2://postgres:palvi123@localhost:5432/ngo_analytics"
)

df.to_sql(
    "program_impact",
    engine,
    if_exists="replace",
    index=False
)
# Out:
# 36
