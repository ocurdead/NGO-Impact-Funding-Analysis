# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\THINKPAD\Downloads\Operations_Monitoring.csv")

# %%
df.head()
# Out:
#   Month  Staff Count  Volunteers  Field Visits  Community Meetings  \
# 0   Jan           24          38            18                   9
# 1   Feb           25          40            20                  10
# 2   Mar           26          42            23                  11
# 3   Apr           27          45            25                  12
# 4   May           28          47            27                  13
#
#    Donor Reports Submitted  Avg Case Response Time Days  Data Quality Score %  \
# 0                        3                          5.4                    86
# 1                        3                          5.1                    87
# 2                        4                          4.9                    88
# 3                        4                          4.6                    89
# 4                        4                          4.4                    90
#
#    Monitoring Visits Completed Operational Risk Level Quarter
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Month                        12 non-null     object
#  1   Staff Count                  12 non-null     int64
#  2   Volunteers                   12 non-null     int64
#  3   Field Visits                 12 non-null     int64
#  4   Community Meetings           12 non-null     int64
#  5   Donor Reports Submitted      12 non-null     int64
#  6   Avg Case Response Time Days  12 non-null     float64
#  7   Data Quality Score %         12 non-null     int64
#  8   Monitoring Visits Completed  12 non-null     int64
#  9   Operational Risk Level       12 non-null     object
#  10  Quarter                      12 non-null     object
# dtypes: float64(1), int64(7), object(3)
# memory usage: 1.2+ KB

# %%
month_map = {
    "Jan": 1,
    "Feb": 2,
    "Mar": 3,
    "Apr": 4,
    "May": 5,
    "Jun": 6,
    "Jul": 7,
    "Aug": 8,
    "Sep": 9,
    "Oct": 10,
    "Nov": 11,
    "Dec": 12
}

df["Month_Number"] = df["Month"].map(month_map).astype(int)

# %%
df.head(12)
# Out:
#    Month  Staff Count  Volunteers  Field Visits  Community Meetings  \
# 0    Jan           24          38            18                   9
# 1    Feb           25          40            20                  10
# 2    Mar           26          42            23                  11
# 3    Apr           27          45            25                  12
# 4    May           28          47            27                  13
# 5    Jun           29          50            30                  14
# 6    Jul           30          53            32                  15
# 7    Aug           31          55            34                  16
# 8    Sep           32          58            37                  17
# 9    Oct           33          61            39                  18
# 10   Nov           34          63            41                  19
# 11   Dec           35          66            44                  20
#
#     Donor Reports Submitted  Avg Case Response Time Days  \
# ...

# %%
df.columns = df.columns.str.lower()
df.columns = df.columns.str.replace(' ','_')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   month                        12 non-null     object
#  1   staff_count                  12 non-null     int64
#  2   volunteers                   12 non-null     int64
#  3   field_visits                 12 non-null     int64
#  4   community_meetings           12 non-null     int64
#  5   donor_reports_submitted      12 non-null     int64
#  6   avg_case_response_time_days  12 non-null     float64
#  7   data_quality_score_%         12 non-null     int64
#  8   monitoring_visits_completed  12 non-null     int64
#  9   operational_risk_level       12 non-null     object
#  10  quarter                      12 non-null     object
#  11  month_number                 12 non-null     int32
# dtypes: float64(1), int32(1), int64(7), object(3)
# ...

# %%
df.rename(columns={"data_quality_score_%": "data_quality_score_pct"}, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   month                        12 non-null     object
#  1   staff_count                  12 non-null     int64
#  2   volunteers                   12 non-null     int64
#  3   field_visits                 12 non-null     int64
#  4   community_meetings           12 non-null     int64
#  5   donor_reports_submitted      12 non-null     int64
#  6   avg_case_response_time_days  12 non-null     float64
#  7   data_quality_score_pct       12 non-null     int64
#  8   monitoring_visits_completed  12 non-null     int64
#  9   operational_risk_level       12 non-null     object
#  10  quarter                      12 non-null     object
#  11  month_number                 12 non-null     int32
# dtypes: float64(1), int32(1), int64(7), object(3)
# ...

# %%
pip install psycopg2-binary sqlalchemy
# Out:
# ...
#
# ...

# %%
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg2://postgres:palvi123@localhost:5432/ngo_analytics"
)

df.to_sql(
    "operations_monitoring",
    engine,
    if_exists="replace",
    index=False
)
# Out:
# 12
