# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\THINKPAD\Downloads\Funding_Donor_Tracking.csv")

# %%
df.head(10)
# Out:
#   Quarter                         Donor Name  Funding Source Type  \
# 0      Q1                       UNHCR Rwanda  Institutional Donor
# 1      Q1  World Food Programme Partner Fund  Institutional Donor
# 2      Q1               Local Private Donors    Private Donations
# 3      Q2         European Humanitarian Fund                Grant
# 4      Q2      Rwanda Community Support Fund          Local Grant
# 5      Q2                       UNHCR Rwanda  Institutional Donor
# 6      Q3  World Food Programme Partner Fund  Institutional Donor
# 7      Q3        Education Access Foundation           Foundation
# 8      Q3               Local Private Donors    Private Donations
# 9      Q4         European Humanitarian Fund                Grant
#
#                  Program Funded  Grant Amount USD  Funding Received USD  \
# 0  Protection & Case Management             85000                 70000
# 1               Food Assistance            120000                100000
# ...

# %%
df.columns = (
    df.columns
      .str.lower()
      .str.replace(" ", "_")
      .str.replace("%", "pct")
)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   quarter                   12 non-null     object
#  1   donor_name                12 non-null     object
#  2   funding_source_type       12 non-null     object
#  3   program_funded            12 non-null     object
#  4   grant_amount_usd          12 non-null     int64
#  5   funding_received_usd      12 non-null     int64
#  6   funding_used_usd          12 non-null     int64
#  7   remaining_budget_usd      12 non-null     int64
#  8   funding_utilization_pct   12 non-null     float64
#  9   cost_per_beneficiary_usd  12 non-null     float64
#  10  reporting_status          12 non-null     object
#  11  program_id                12 non-null     object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 1.3+ KB

# %%
(
    df["funding_received_usd"]
    - df["funding_used_usd"]
    == df["remaining_budget_usd"]
).all()
# Out:
# True

# %%
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg2://postgres:palvi123@localhost:5432/ngo_analytics"
)

df.to_sql(
    "donor_track",
    engine,
    if_exists="replace",
    index=False
)
# Out:
# 12
